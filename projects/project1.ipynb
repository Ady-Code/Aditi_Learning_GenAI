# %% [markdown]
# ## Scenario: E-commerce Order Processing System
#
# You run an online store.
# You have orders. You want to:
#
# * Filter valid orders
# * Apply discounts
# * Calculate totals
#
# We’ll use:
#
# * `lambda`
# * `map`
# * `filter`
# * `reduce`

# %%
# Step 0 — Sample Data

orders = [
    {"id": 1, "customer": "Amit", "amount": 1200, "status": "completed"},
    {"id": 2, "customer": "Neha", "amount": 800, "status": "cancelled"},
    {"id": 3, "customer": "Raj", "amount": 1500, "status": "completed"},
    {"id": 4, "customer": "Sara", "amount": 400, "status": "completed"},
]

# %% [markdown]
# You need to perform below :
# - Filter all completed orders using python fucntion.
# - Filter all completed orders using lambda fucntion.
# - Apply 10% discount on all completed orders using python fucntion.
# - Apply 10% discount on all completed orders using lambda fucntion.
# - Calcualte total revenue by adding all amounts of all completed orders using python function.
# - Calcualte total revenue by adding all amounts of all completed orders using lambda function.
# - Apply user defined discount whcih can change on all completed orders. (hint you might need to use lambda function here along with python function)

# %%
# Code for filter all completed orders using python fucntion 

orders = [
    {"id": 1, "customer": "Amit", "amount": 1200, "status": "completed"},
    {"id": 2, "customer": "Neha", "amount": 800, "status": "cancelled"},
    {"id": 3, "customer": "Raj", "amount": 1500, "status": "completed"},
    {"id": 4, "customer": "Sara", "amount": 400, "status": "completed"},
]
result = []
for order in orders:
    if order["status"]=='completed':
        result.append(order)

print(result)
# Out:
# [{'id': 1, 'customer': 'Amit', 'amount': 1200, 'status': 'completed'}, {'id': 3, 'customer': 'Raj', 'amount': 1500, 'status': 'completed'}, {'id': 4, 'customer': 'Sara', 'amount': 400, 'status': 'completed'}]

# %%
# Code for filter all completed orders using lambda fucntion 
orders = [
    {"id": 1, "customer": "Amit", "amount": 1200, "status": "completed"},
    {"id": 2, "customer": "Neha", "amount": 800, "status": "cancelled"},
    {"id": 3, "customer": "Raj", "amount": 1500, "status": "completed"},
    {"id": 4, "customer": "Sara", "amount": 400, "status": "completed"},
]
completed_order = list(filter(lambda order: order["status"]=='completed', orders))
print(completed_order)
# Out:
# [{'id': 1, 'customer': 'Amit', 'amount': 1200, 'status': 'completed'}, {'id': 3, 'customer': 'Raj', 'amount': 1500, 'status': 'completed'}, {'id': 4, 'customer': 'Sara', 'amount': 400, 'status': 'completed'}]

# %%
# Code to apply 10% discount on all completed orders using python fucntion 

orders = [
    {"id": 1, "customer": "Amit", "amount": 1200, "status": "completed"},
    {"id": 2, "customer": "Neha", "amount": 800, "status": "cancelled"},
    {"id": 3, "customer": "Raj", "amount": 1500, "status": "completed"},
    {"id": 4, "customer": "Sara", "amount": 400, "status": "completed"},
]

result = []
def disc_order():
    for order in orders:
        if order["status"] == "completed":
            result.append(order)
            order["amount"] = order["amount"] * 0.9
    print(result)

disc_order()
# Out:
# [{'id': 1, 'customer': 'Amit', 'amount': 1080.0, 'status': 'completed'}, {'id': 3, 'customer': 'Raj', 'amount': 1350.0, 'status': 'completed'}, {'id': 4, 'customer': 'Sara', 'amount': 360.0, 'status': 'completed'}]

# %%
# Code to apply 10% discount on all completed orders using lambda fucntion 

orders = [
    {"id": 1, "customer": "Amit", "amount": 1200, "status": "completed"},
    {"id": 2, "customer": "Neha", "amount": 800, "status": "cancelled"},
    {"id": 3, "customer": "Raj", "amount": 1500, "status": "completed"},
    {"id": 4, "customer": "Sara", "amount": 400, "status": "completed"},
]

def disc_order(order):
    order["amount"] = order["amount"] * 0.9
    return order

new_order = (list(map(disc_order, filter(lambda order: order["status"] == "completed", orders))))
print(new_order)
# Out:
# [{'id': 1, 'customer': 'Amit', 'amount': 1080.0, 'status': 'completed'}, {'id': 3, 'customer': 'Raj', 'amount': 1350.0, 'status': 'completed'}, {'id': 4, 'customer': 'Sara', 'amount': 360.0, 'status': 'completed'}]

# %%
# Calcualte total revenue by adding all amounts of all completed orders using python function
orders = [
    {"id": 1, "customer": "Amit", "amount": 1200, "status": "completed"},
    {"id": 2, "customer": "Neha", "amount": 800, "status": "cancelled"},
    {"id": 3, "customer": "Raj", "amount": 1500, "status": "completed"},
    {"id": 4, "customer": "Sara", "amount": 400, "status": "completed"},
]

def all_amount():
    total = 0
    for order in orders:
        if order["status"] == 'completed':
            total += order["amount"]
    print(f"Total revenue for completed orders: {total}")

all_amount()
# Out:
# Total revenue for completed orders: 3100

# %%
# Calcualte total revenue by adding all amounts of all completed orders using lambda function
from functools import reduce
orders = [
    {"id": 1, "customer": "Amit", "amount": 1200, "status": "completed"},
    {"id": 2, "customer": "Neha", "amount": 800, "status": "cancelled"},
    {"id": 3, "customer": "Raj", "amount": 1500, "status": "completed"},
    {"id": 4, "customer": "Sara", "amount": 400, "status": "completed"},
]

completed_order = reduce(lambda total, order: total + order["amount"] if order["status"] =='completed' else total, orders,0)
print(f"Total revenue: {completed_order}")
# Out:
# Total revenue: 3100

# %%
# Apply user defined discount whcih can change on all completed orders using python function.

orders = [
    {"id": 1, "customer": "Amit", "amount": 1200, "status": "completed"},
    {"id": 2, "customer": "Neha", "amount": 800, "status": "cancelled"},
    {"id": 3, "customer": "Raj", "amount": 1500, "status": "completed"},
    {"id": 4, "customer": "Sara", "amount": 400, "status": "completed"},
]
# my_list = []
# def apply_discount(discount):
#     for order in orders:
#         if order["status"] == "completed":
#             # final_result = list(filter(lambda order:order["amount"] * (1-discount/100), orders))
#             # print(final_result)
#             order["amount"] = order["amount"] * (1-discount/100)
#             # print(order)
#             my_list.append(order)
#     print(my_list)

def apply_discount(discount):
    order["amount"] = order["amount"] * (1-discount/100)
    return order

def final_order(discount):
    completed_order = list(filter(lambda order: order["status"] == "completed", orders))
    new_order = list(map(lambda order: apply_discount(discount),completed_order))
    return new_order
print(final_order(20))
# new_order = (list(map(disc_order, filter(lambda order: order["status"] == "completed", orders))))
# completed_order = list(filter(lambda order: order["status"] == "completed", orders))
# new_order = list(map(apply_discount(20), completed_order))
# apply_discount(20)
# Out:
# [{'id': 1, 'customer': 'Amit', 'amount': 8.854437155380598, 'status': 'completed'}, {'id': 1, 'customer': 'Amit', 'amount': 8.854437155380598, 'status': 'completed'}, {'id': 1, 'customer': 'Amit', 'amount': 8.854437155380598, 'status': 'completed'}]
