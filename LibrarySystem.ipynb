# %%
books = {
    "B101": {"title": "To Kill a Mockingbird", "author": "Harper Lee", "category": "Fiction", "copies": 5},
    "B102": {"title": "Pride and Prejudice", "author": "Jane Austen", "category": "Romance", "copies": 6},
    "B103": {"title": "The Hobbit", "author": "J.R.R. Tolkien", "category": "Fantasy", "copies": 7},
    "B104": {"title": "The Catcher in the Rye", "author": "J.D. Salinger", "category": "Fiction", "copies": 3},
    "B105": {"title": "The Alchemist", "author": "Paulo Coelho", "category": "Adventure", "copies": 9},
    "B106": {"title": "The Da Vinci Code", "author": "Dan Brown", "category": "Thriller", "copies": 5},
    "B107": {"title": "The Lord of the Rings", "author": "J.R.R. Tolkien", "category": "Fantasy", "copies": 4},
    "B108": {"title": "Harry Potter and the Sorcerer's Stone", "author": "J.K. Rowling", "category": "Fantasy", "copies": 10}
}

users = {
    "U001": {"name": "Alice Johnson", "borrowed_books": ["B101", "B105"]},
    "U002": {"name": "Bob Smith", "borrowed_books": ["B102"]},
    "U003": {"name": "Charlie Brown", "borrowed_books": []},
    "U004": {"name": "Diana Prince", "borrowed_books": ["B110", "B104"]},
    "U005": {"name": "Ethan Hunt", "borrowed_books": ["B108"]}
}

borrow_history = [ ("U001", "B101"), ("U001", "B105"),("U002", "B102"),("U004", "B110"),("U004", "B104"),("U005", "B108")]

books_category = {"Fiction", "Romance", "Fantasy", "Adventure","Thriller"}

# 1. ADDING BOOK : Update category set , Prevent duplicate Book IDs
def add_book():

        book_id = input("Enter book id")

        if book_id in books:
            print("book ID already exist")
        title = input("Enter title")
        author = input("Enter author")
        category = input("Enter category")
        try:
            copies = int(input("Enter number of copies"))
        except Exception as e:
            print(f"Error: {e}")
        books[book_id] = {"title":title,
                        "author": author,
                        "category": category,
                        "copies": copies}
        
        print(books)
        books_category.add("Non fiction")
