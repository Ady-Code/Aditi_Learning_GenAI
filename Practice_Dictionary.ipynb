# %%
MLB_teams = {
"Colorado": "Rockies",
"Chicago": "White Sox",
"Chicago": "Cubs",
"Boston": "Red Sox",
"Minnesota": "Twins",
"Milwaukee": "Brewers",
"Seattle": "Mariners"}

print(MLB_teams)
# Out:
# {'Colorado': 'Rockies', 'Chicago': 'Cubs', 'Boston': 'Red Sox', 'Minnesota': 'Twins', 'Milwaukee': 'Brewers', 'Seattle': 'Mariners'}

# %%
{
    "colors": ["red", "green", "blue"],
"plugins": {"py_code", "dev_sugar", "fasting_py"},
"timeout": 3,
"position": Point(42, 21)
}
