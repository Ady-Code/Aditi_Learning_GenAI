# %%
lst=[{'order_id': '1001', 'customer': 'Alice', 'timestamp': '2026-01-01T10:00:00', 'product': 'Laptop', 'quantity': '1', 'price': '70000', 'status': 'completed'}, 
 {'order_id': '1002', 'customer': 'Bob', 'timestamp': '2026-01-01T10:05:00', 'product': 'Mouse', 'quantity': '2', 'price': '500', 'status': 'completed'}, 
 {'order_id': '1003', 'customer': 'Alice', 'timestamp': '2026-01-01T10:07:00', 'product': 'Keyboard', 'quantity': '1', 'price': '2000', 'status': 'completed'}]
# for i in lst:
#     print(i)
#     lst.pop(i)
# print(lst)
lst = [i for i in lst if i["customer"] != 'Alice']
print(lst)

# lst.pop(1) 
# print(lst)
# Out:
# [{'order_id': '1002', 'customer': 'Bob', 'timestamp': '2026-01-01T10:05:00', 'product': 'Mouse', 'quantity': '2', 'price': '500', 'status': 'completed'}]
