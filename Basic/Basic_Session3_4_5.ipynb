# %% [markdown]
# - _test --> private variable
# - f string
# - `print("Hi{f_name} {l_name}".format(f_name = "Aditi", l_name = "Goel"))`
# - swapping
# - dunder --> double under(underscore) methods
#     - special predefined methods having 2 prefix and 2 suffix underscores
#     - magic methods
#     - __str__, __init__, __le__, __pow__
#
# - dir(float) or dir(5.7)
# - help(int) or help(5)
# - help(round)
#  ### Input() function & Type Casting
#
# - input() --> always returns text (string)
#     - explicitly change type if required
#
# ### Advanced Math
# - `**` Exponent --> 2 ** 3 = 8
# - `//` Floor division --> chops off decimal --> 10 // 3 = 3
# - `%` Modulo --> 10 % 3 = 1
#     - detects even/odd numbers
#     - helps in cycling loops
# - `bool(65)`, `bool("Hello")`, `bool("0")`, `bool("False")` --> True
# - `bool("")`, `bool(0)`, `bool(0.0)`, `bool(None)` --> False
# - `num = 7`
#     `bool(num % 2)` --> True
# - `num = 8`
#     `bool(num % 2)` --> False
# - Comparison Operators --> returns True or False
#     - `==`, `!=`, `>`, `<`, `>=`, `<=`
# - Assignment (=)
# - Assignment shortcuts
#     - `x +=1`, `x -= 5`, `x *= 2`
