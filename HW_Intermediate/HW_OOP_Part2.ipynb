# %%
# Level 1: The Marketing Team (Is-A) 🌳
# Create a Marketer class that inherits from our standard Employee class.
# Give it a method run_campaign() that prints "[Name] is running Facebook ads."
# Create a Marketer object and call the method.

# %%
# Level 2: The super() Upgrade 🚀
# Create a Designer class inheriting from Employee.
# Write a new __init__ that takes name, department, salary, and design_tool.
# Use super().__init__ to handle the first three, and manually set self.design_tool.
# Create a Designer named "Bob" using "Figma" and print his tool.

# %%
# Level 3: The Office (Composition / Has-A) 🏢
# Create a class Office.
# __init__(self, location) should set the location and create an empty list self.employees = [].
# Method add_employee(self, emp): Appends an employee object to the list.
# Method roll_call(self): Loops through self.employees and prints their names.
# Create an Office, add 2 Employees to it, and run the roll call.

# %%
# Level 4: The Strict CEO (Abstraction) 📐
# Create an abstract class Contractor(ABC).
# Give it an @abstractmethod called get_hourly_rate(self).
# Create a class FreelanceDeveloper(Contractor). If you don't write get_hourly_rate(), it should fail. Write it to return 75.
# Instantiate the Freelancer and print their rate.

# %%
# Level 5: The Payroll System (Real Scenario) 💰
# Scenario: Combine Inheritance, Composition, and Abstraction to pay everyone!

# Use the AbstractEmployee class from Topic 4 (with the abstract calculate_bonus method).
# Create FullTimeDev(AbstractEmployee): Bonus is 10% of their salary.
# Create SalesManager(AbstractEmployee): Bonus is 20% of their salary.
# Create a PayrollSystem class (Composition).
# It has a self.staff = [] list.
# add_staff(employee) method.
# process_bonuses() method that loops through all staff and prints "[Name] gets $[Bonus]".
# Test: Add a Dev and a SalesManager to Payroll, then process the bonuses!
