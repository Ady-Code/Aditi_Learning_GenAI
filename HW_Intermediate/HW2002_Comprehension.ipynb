# %%
# Level 1: The Number Doubler ✖️2

# numbers = [1, 2, 3, 4, 5]
# doubled = []
# for num in numbers:
#     doubled.append(num * 2)

numbers = [1, 2, 3, 4, 5]
doubled = [num * 2 for num in numbers]
print(doubled)
# Out:
# [2, 4, 6, 8, 10]

# %%
# Level 2: The Name Cleaner 🧹

# Refactor this code. We want to strip spaces and title case the names.

# names = ["  alice ", "  bob", "charlie  "]
# clean_names = []
# for name in names:
#     clean_names.append(name.strip().title())

names = ["  alice ", "  bob", "charlie  "]
clean_names = [name.strip().title() for name in names]

print(clean_names)
# Out:
# ['Alice', 'Bob', 'Charlie']

# %%
# Level 3: The Filter (Over $10) 💰

prices = [5, 12, 3, 50, 8, 20]

gt10 = [price for price in prices if price > 10]
print(gt10)
# Out:
# [12, 50, 20]

# %%
# Level 4: The Length Mapper (Dicts)

sentence = "Python is awesome"
sentence_list = sentence.split()
# print(sentence_list)
# my_dict = {k, len(v) for k,v in zip(keys,values)}
new_list = [len(word) for word in sentence_list]
# print(new_list)
my_dict = {k:v for k,v in zip(sentence_list,new_list)}
print(my_dict)
# my_dict = {k:v for k,v in zip(sentence_list,[len(word) for word in sentence_list])}
# print(my_dict)


# for word in sentence_list:
#     print(word)
#     print(len(word))
    
#     print(list(zip(word, len(word))))
#     for k,v in zip(word,len(word)):
#         if isinstance(v, str):
#             print(word)
# Out:
# {'Python': 6, 'is': 2, 'awesome': 7}

# %%
# Level 5: The "Matrix" Flattener (Hard) 🧊
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

my_list = [flat_list for element in matrix for flat_list in element]
print(my_list)
# for element in matrix:
#     print(element)
#     for flat_list in element:
#         print(flat_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Level 1: Temperature Converter
# You are given a list of temperatures recorded during the day (in Celsius). Create a new list containing temperatures converted to Fahrenheit.

# temperatures = [18, 22, 25, 17, 30, 28]

# Formula: F = (C × 9/5) + 32

# %%
# Level 2: The Domain Extractor 🧹
# You are given a list of website visits. Create a set containing unique domain names using set comprehension.

# urls = [     "google.com",     "openai.com",     "google.com",     "github.com",     "openai.com" ]

# %%
# Level 3: The Product Value Creator 💰
# You are given a list of product names.

# products = ["Laptop", "Mouse", "Keyboard"]

# Create a dictionary where:

# the key is the product name
# the value is the length of the product name

# %%
# Level 4: Cube Generator
# Take a input from user and create a generator expression taht produces cube of each number divisible by 3 between 0 and user entered number.

# User input should be between 0 to 10000.

# %%
# Level 5: The "Matrix" Flattener (Hard) 🧊
# You have a 2D list (a list of lists): matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]] 
# Use a comprehension to flatten it into a single list: [1, 2, 3, 4, 5, 6, 7, 8, 9]. 
# Hint: You need two for keywords inside the square brackets.
