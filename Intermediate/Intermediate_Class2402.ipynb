# %%
from random import randint
abc = randint(1,10)
user = int(input("Enter your number"))

if user < abc:
    print("Too low")
elif user > abc:
    print("Too high")
else:
    print("you guessed it right")

# %%
# players roll the dice
from random import randint
# dice = randint(1,6)
# print(dice)

def rolldice():
        dice = randint(1,6)
        print(dice)
        if dice == 6:
# if 6, roll until next number is not 6, max tries 3
            for j in range(0,3):
                print("roll the dice again")
                rolldice = randint(1,6)
                print(rolldice)
                if rolldice != 6:
                     break
                else:
                     j +=1
                continue
                
# continue on other numbers
        else:
             print("next member turn")


rolldice()
# Out:
# 6
# roll the dice again
# 4

# %%
# players roll the dice
from random import randint
# dice = randint(1,6)
# print(dice)
prev_roll = []

def nextroll():
     return randint(1,6)

def rolldice():
        for j in range(0,3):
            dice = nextroll()
            prev_roll.append(dice)
            print(prev_roll)
            if dice == 6:
                # return dice
                continue
                # dice = nextroll()
# if 6, roll until next number is not 6, max tries 3
                
                
# continue on other numbers
            else:
                break
        print(prev_roll[j])
        print(j)
        # return dice


rolldice()
# Out:
# [6]
# [6, 2]
# 2
# 1

# %%
# head and tail

from random import choice

def flip_coin():
    return choice(["head","tail"])

def user_choice():
    user = input("Enter your choice")
    sys_choice = flip_coin()
    print(sys_choice)
    while user != sys_choice:
        print("Try again")
        break
    
user_choice()
# Out:
# head
# Try again

# %%
# head and tail

from random import choice
def flip_coin():
    return choice(["head","tail"])

i = 0
my_dict = {}
is_continue = True
prev_sys_choice = []
prev_user_choice = []

while is_continue:
    user = input("Enter your choice").lower()
    sys_choice = flip_coin()
    # if i > 0: # uncomment if prev choice doesn't need to be captured in the last case
    #     prev_sys_choice.append(sys_choice)
    #     prev_user_choice.append(user)
    # i += 1
    if user != sys_choice:
            print("Try again")  
    else:
        is_continue = False
    prev_sys_choice.append(sys_choice)
    prev_user_choice.append(user)    
    for i in range(len(prev_user_choice)):
        my_dict[f"Chance{i+1}"] = {"User selection": prev_user_choice[i], "System selection": prev_sys_choice[i]}
    # print(f"{i}: sys: {prev_sys_choice}, user: {prev_user_choice}")

    # my_dict = dict(zip(prev_sys_choice,prev_user_choice))
    # print(f"Chance{i}: {{System selection: {prev_sys_choice}, User selection: {prev_user_choice}}}")
print("history:")
print("{", end="\n")
print(my_dict)

# history
# chance1: {your selection:head, his selection:tail},
# chance2: {your selection:head, his selection:head}
# Out:
# history:
# {
# {'Chance1': {'User selection': 'head', 'System selection': 'head'}}

# %%
# head and tail

from random import choice
def flip_coin():
    return choice(["head","tail"])

my_dict = {}
is_continue = True
prev_sys_choice = []
prev_user_choice = []

while is_continue:
    user = input("Enter your choice").lower()
    sys_choice = flip_coin()
    if user != sys_choice:
            print("Try again")  
    else:
        is_continue = False
    prev_sys_choice.append(sys_choice)
    prev_user_choice.append(user)    
    for i in range(len(prev_user_choice)):
        my_dict[f"Chance{i+1}"] = {"User selection": prev_user_choice[i], "System selection": prev_sys_choice[i]}
print("history:")
print("{", end="\n")
print(my_dict)

# history
# chance1: {your selection:head, his selection:tail},
# chance2: {your selection:head, his selection:head}
# Out:
# Try again
# history:
# {
# {'Chance1': {'User selection': 'head', 'System selection': 'tail'}, 'Chance2': {'User selection': 'head', 'System selection': 'head'}}
